# %%
sum([10,20,30])
# Out:
# 60

# %%
lst = [10,20,30]
sum(lst) # lst is the input of this funtion
# be careful about brackets
# Out:
# 60

# %%
len(lst)
# functions can take more than one inputs. we will see later
# Out:
# 3

# %%
listlength = len(lst)
print(listlength)
# Out:
# 3

# %%
# Exercise:

# Compute the average the lst

theaverage = sum(lst)/len(lst)
theaverage
# Out:
# 20.0
